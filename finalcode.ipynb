# %% [markdown]
# <a href="https://colab.research.google.com/github/01fe22bec002/ml_model_3/blob/main/finalcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 1. INSTALL DEPENDENCIES (if not preinstalled) ---
# !pip install -q pandas numpy scikit-learn tensorflow joblib

# --- 2. IMPORT LIBRARIES ---
import pandas as pd
import numpy as np
import os
import joblib
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# --- 3. LOAD DATA ---
train_df = pd.read_csv("/content/Training.csv")
test_df = pd.read_csv("/content/Testing.csv")

# Drop unnamed column if exists
if 'Unnamed: 133' in train_df.columns:
    train_df.drop('Unnamed: 133', axis=1, inplace=True)

# --- 4. DATA CHECKS ---
print("Training Shape:", train_df.shape)
print("Test Shape:", test_df.shape)
print("Nulls in Training:", train_df.isnull().sum().sum())
print("Unique Diseases:", train_df['prognosis'].nunique())

# --- 5. ENCODING & SPLIT ---
X_train = train_df.drop("prognosis", axis=1)
y_train = train_df["prognosis"]
X_test = test_df.drop("prognosis", axis=1)
y_test = test_df["prognosis"]

label_encoder = LabelEncoder()
y_train_enc = label_encoder.fit_transform(y_train)
y_test_enc = label_encoder.transform(y_test)

# Save label encoder
os.makedirs("models", exist_ok=True)
joblib.dump(label_encoder, "models/label_encoder.pkl")

# --- 6. TRAIN-VAL SPLIT ---
X_train_split, X_val, y_train_split, y_val = train_test_split(
    X_train, y_train_enc, test_size=0.2, stratify=y_train_enc, random_state=42
)

# --- 7. SCALING FOR NN ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_split)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

joblib.dump(scaler, "models/scaler.pkl")

# --- 8. RANDOM FOREST ---
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_split, y_train_split)

# Validation RF
rf_val_preds = rf_model.predict(X_val)
print("RF Val Accuracy:", accuracy_score(y_val, rf_val_preds))

# Save RF
joblib.dump(rf_model, "models/random_forest_model.pkl")

# --- 9. FEEDFORWARD NEURAL NETWORK ---
input_dim = X_train_scaled.shape[1]
num_classes = len(label_encoder.classes_)

fnn_model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(num_classes, activation='softmax')
])

fnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

fnn_model.fit(X_train_scaled, y_train_split, validation_data=(X_val_scaled, y_val),
              epochs=100, batch_size=32, callbacks=[early_stop], verbose=1)

fnn_model.save("models/fnn_model.keras")

# --- 10. TEST EVALUATION ---

# RF
rf_preds_test = rf_model.predict(X_test)
print("RF Test Accuracy:", accuracy_score(y_test_enc, rf_preds_test))
print(classification_report(y_test_enc, rf_preds_test, target_names=label_encoder.classes_))

# FNN
fnn_preds_test = fnn_model.predict(X_test_scaled)
fnn_preds_class = np.argmax(fnn_preds_test, axis=1)
print("FNN Test Accuracy:", accuracy_score(y_test_enc, fnn_preds_class))
print(classification_report(y_test_enc, fnn_preds_class, target_names=label_encoder.classes_))

# --- 11. SAVE SYMPTOM LIST ---
symptom_list = list(X_train.columns)
joblib.dump(symptom_list, "models/symptom_list.pkl")
# --- 1. INSTALL DEPENDENCIES (if not preinstalled) ---
# !pip install -q pandas numpy scikit-learn tensorflow joblib

# --- 2. IMPORT LIBRARIES ---
import pandas as pd
import numpy as np
import os
import joblib
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# --- 3. LOAD DATA ---
train_df = pd.read_csv("/content/Training.csv")
test_df = pd.read_csv("/content/Testing.csv")

# Drop unnamed column if exists
if 'Unnamed: 133' in train_df.columns:
    train_df.drop('Unnamed: 133', axis=1, inplace=True)

# --- 4. DATA CHECKS ---
print("Training Shape:", train_df.shape)
print("Test Shape:", test_df.shape)
print("Nulls in Training:", train_df.isnull().sum().sum())
print("Unique Diseases:", train_df['prognosis'].nunique())

# --- 5. ENCODING & SPLIT ---
X_train = train_df.drop("prognosis", axis=1)
y_train = train_df["prognosis"]
X_test = test_df.drop("prognosis", axis=1)
y_test = test_df["prognosis"]

label_encoder = LabelEncoder()
y_train_enc = label_encoder.fit_transform(y_train)
y_test_enc = label_encoder.transform(y_test)

# Save label encoder
os.makedirs("models", exist_ok=True)
joblib.dump(label_encoder, "models/label_encoder.pkl")

# --- 6. TRAIN-VAL SPLIT ---
X_train_split, X_val, y_train_split, y_val = train_test_split(
    X_train, y_train_enc, test_size=0.2, stratify=y_train_enc, random_state=42
)

# --- 7. SCALING FOR NN ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_split)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

joblib.dump(scaler, "models/scaler.pkl")

# --- 8. RANDOM FOREST ---
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_split, y_train_split)

# Validation RF
rf_val_preds = rf_model.predict(X_val)
print("RF Val Accuracy:", accuracy_score(y_val, rf_val_preds))

# Save RF
joblib.dump(rf_model, "models/random_forest_model.pkl")

# --- 9. FEEDFORWARD NEURAL NETWORK ---
input_dim = X_train_scaled.shape[1]
num_classes = len(label_encoder.classes_)

fnn_model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(num_classes, activation='softmax')
])

fnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

fnn_model.fit(X_train_scaled, y_train_split, validation_data=(X_val_scaled, y_val),
              epochs=100, batch_size=32, callbacks=[early_stop], verbose=1)

fnn_model.save("models/fnn_model.keras")

# --- 10. TEST EVALUATION ---

# RF
rf_preds_test = rf_model.predict(X_test)
print("RF Test Accuracy:", accuracy_score(y_test_enc, rf_preds_test))
print(classification_report(y_test_enc, rf_preds_test, target_names=label_encoder.classes_))

# FNN
fnn_preds_test = fnn_model.predict(X_test_scaled)
fnn_preds_class = np.argmax(fnn_preds_test, axis=1)
print("FNN Test Accuracy:", accuracy_score(y_test_enc, fnn_preds_class))
print(classification_report(y_test_enc, fnn_preds_class, target_names=label_encoder.classes_))

# --- 11. SAVE SYMPTOM LIST ---
symptom_list = list(X_train.columns)
joblib.dump(symptom_list, "models/symptom_list.pkl")
# Out:
# Training Shape: (4920, 133)
# Test Shape: (42, 133)
# Nulls in Training: 0
# Unique Diseases: 41
# RF Val Accuracy: 1.0
# Epoch 1/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4194 - loss: 2.5978 - val_accuracy: 1.0000 - val_loss: 0.0553
# Epoch 2/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9830 - loss: 0.1593 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 3/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9963 - loss: 0.0460 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 4/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9981 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 9.6114e-04
# Epoch 5/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9997 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 4.8574e-04
# Epoch 6/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9996 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 2.8011e-04
# Epoch 7/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9989 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 1.6714e-04
# Epoch 8/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9997 - loss: 0.0075 - val_accuracy: 1.0000 - val_loss: 1.4510e-04
# Epoch 9/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9998 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 1.2722e-04
# Epoch 10/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9982 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 7.2485e-05
# Epoch 11/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9993 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 7.6320e-05
# Epoch 12/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 3.1057e-05
# Epoch 13/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9993 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 4.3815e-05
# Epoch 14/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9994 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 3.5732e-05
# Epoch 15/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9996 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 7.8230e-05
# Epoch 16/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9996 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 1.5352e-05
# Epoch 17/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 9.9136e-06
# Epoch 18/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 8.3293e-06
# Epoch 19/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9999 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 1.1103e-05
# Epoch 20/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9999 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 9.0598e-06
# Epoch 21/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 8.3029e-04 - val_accuracy: 1.0000 - val_loss: 3.9503e-06
# Epoch 22/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 7.6532e-06
# Epoch 23/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 3.8085e-06
# Epoch 24/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 6.8672e-06
# Epoch 25/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.4481e-04 - val_accuracy: 1.0000 - val_loss: 2.0874e-06
# Epoch 26/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.2590e-04 - val_accuracy: 1.0000 - val_loss: 1.5943e-06
# Epoch 27/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.8650e-04 - val_accuracy: 1.0000 - val_loss: 1.9105e-06
# Epoch 28/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 2.3227e-06
# Epoch 29/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 7.6077e-04 - val_accuracy: 1.0000 - val_loss: 1.4291e-06
# Epoch 30/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 3.5709e-04 - val_accuracy: 1.0000 - val_loss: 1.1471e-06
# Epoch 31/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 8.5370e-07
# Epoch 32/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9991 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 2.7846e-06
# Epoch 33/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 4.0194e-06
# Epoch 34/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.4937e-04 - val_accuracy: 1.0000 - val_loss: 1.4292e-06
# Epoch 35/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 6.2951e-04 - val_accuracy: 1.0000 - val_loss: 5.5161e-06
# Epoch 36/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9993 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 4.8107e-07
# Epoch 37/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 4.2503e-04 - val_accuracy: 1.0000 - val_loss: 3.9772e-07
# Epoch 38/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.3899e-04 - val_accuracy: 1.0000 - val_loss: 5.9883e-06
# Epoch 39/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.0469e-04 - val_accuracy: 1.0000 - val_loss: 9.7472e-07
# Epoch 40/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 3.8113e-07
# Epoch 41/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.8681e-04 - val_accuracy: 1.0000 - val_loss: 2.8045e-07
# Epoch 42/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.6978e-04 - val_accuracy: 1.0000 - val_loss: 8.8423e-07
# Epoch 43/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 3.1801e-07
# Epoch 44/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 5.9837e-04 - val_accuracy: 1.0000 - val_loss: 2.3575e-07
# Epoch 45/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.7509e-04 - val_accuracy: 1.0000 - val_loss: 2.2206e-07
# Epoch 46/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 8.1662e-04 - val_accuracy: 1.0000 - val_loss: 2.4120e-07
# Epoch 47/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.5694e-04 - val_accuracy: 1.0000 - val_loss: 2.0341e-07
# Epoch 48/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.7265e-04 - val_accuracy: 1.0000 - val_loss: 1.4574e-07
# Epoch 49/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4784e-04 - val_accuracy: 1.0000 - val_loss: 2.3466e-07
# Epoch 50/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.0454e-04 - val_accuracy: 1.0000 - val_loss: 1.1723e-06
# Epoch 51/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.3268e-04 - val_accuracy: 1.0000 - val_loss: 6.2869e-07
# Epoch 52/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.6435e-04 - val_accuracy: 1.0000 - val_loss: 2.2775e-07
# Epoch 53/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9998 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 1.8153e-06
# Epoch 54/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.4205e-04 - val_accuracy: 1.0000 - val_loss: 2.1758e-07
# Epoch 55/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.9492e-04 - val_accuracy: 1.0000 - val_loss: 8.6984e-08
# Epoch 56/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9994 - loss: 8.3784e-04 - val_accuracy: 1.0000 - val_loss: 8.0926e-08
# Epoch 57/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.2616e-04 - val_accuracy: 1.0000 - val_loss: 7.4142e-08
# Epoch 58/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.0393e-05 - val_accuracy: 1.0000 - val_loss: 5.5728e-08
# Epoch 59/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.3080e-04 - val_accuracy: 1.0000 - val_loss: 4.6763e-08
# Epoch 60/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.0649e-04 - val_accuracy: 1.0000 - val_loss: 5.4758e-08
# Epoch 61/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.3252e-04 - val_accuracy: 1.0000 - val_loss: 8.2380e-08
# Epoch 62/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9996 - loss: 5.3298e-04 - val_accuracy: 1.0000 - val_loss: 1.1218e-07
# Epoch 63/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.6550e-05 - val_accuracy: 1.0000 - val_loss: 8.1290e-08
# Epoch 64/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8968e-04 - val_accuracy: 1.0000 - val_loss: 3.8404e-08
# Epoch 65/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.1883e-04 - val_accuracy: 1.0000 - val_loss: 2.4472e-08
# Epoch 66/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 8.9707e-04 - val_accuracy: 1.0000 - val_loss: 2.7864e-08
# Epoch 67/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5774e-04 - val_accuracy: 1.0000 - val_loss: 2.7137e-08
# Epoch 68/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9998 - loss: 6.6358e-04 - val_accuracy: 1.0000 - val_loss: 9.1587e-08
# Epoch 69/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 1.3548e-06
# Epoch 70/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.9298e-04 - val_accuracy: 1.0000 - val_loss: 5.3668e-08
# Epoch 71/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.7536e-04 - val_accuracy: 1.0000 - val_loss: 4.0221e-08
# Epoch 72/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.6483e-04 - val_accuracy: 1.0000 - val_loss: 7.2930e-08
# Epoch 73/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.7197e-04 - val_accuracy: 1.0000 - val_loss: 2.6652e-08
# Epoch 74/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.3298e-05 - val_accuracy: 1.0000 - val_loss: 1.5749e-08
# Epoch 75/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.7887e-05 - val_accuracy: 1.0000 - val_loss: 1.3690e-08
# Epoch 76/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9993 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 4.2886e-08
# Epoch 77/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 6.1203e-04 - val_accuracy: 1.0000 - val_loss: 2.6438e-05
# Epoch 78/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 4.5610e-04 - val_accuracy: 1.0000 - val_loss: 2.0837e-08
# Epoch 79/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 3.4205e-04 - val_accuracy: 1.0000 - val_loss: 5.9847e-08
# Epoch 80/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.8850e-04 - val_accuracy: 1.0000 - val_loss: 4.0948e-08
# Epoch 81/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 6.5783e-08
# Epoch 82/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.8128e-04 - val_accuracy: 1.0000 - val_loss: 3.4527e-08
# Epoch 83/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.5445e-05 - val_accuracy: 1.0000 - val_loss: 2.4108e-08
# Epoch 84/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.3516e-05 - val_accuracy: 1.0000 - val_loss: 1.5991e-08
# Epoch 85/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.2669e-04 - val_accuracy: 1.0000 - val_loss: 4.6036e-08
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7beb264923e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# RF Test Accuracy: 0.9761904761904762
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00         1
#                                    AIDS       1.00      1.00      1.00         1
#                                    Acne       1.00      1.00      1.00         1
#                     Alcoholic hepatitis       1.00      1.00      1.00         1
#                                 Allergy       1.00      1.00      1.00         1
#                               Arthritis       1.00      1.00      1.00         1
#                        Bronchial Asthma       1.00      1.00      1.00         1
#                    Cervical spondylosis       1.00      1.00      1.00         1
#                             Chicken pox       0.50      1.00      0.67         1
#                     Chronic cholestasis       1.00      1.00      1.00         1
#                             Common Cold       1.00      1.00      1.00         1
#                                  Dengue       1.00      1.00      1.00         1
#                               Diabetes        1.00      1.00      1.00         1
#            Dimorphic hemmorhoids(piles)       1.00      1.00      1.00         1
#                           Drug Reaction       1.00      1.00      1.00         1
#                        Fungal infection       1.00      0.50      0.67         2
#                                    GERD       1.00      1.00      1.00         1
#                         Gastroenteritis       1.00      1.00      1.00         1
#                            Heart attack       1.00      1.00      1.00         1
#                             Hepatitis B       1.00      1.00      1.00         1
#                             Hepatitis C       1.00      1.00      1.00         1
#                             Hepatitis D       1.00      1.00      1.00         1
#                             Hepatitis E       1.00      1.00      1.00         1
#                           Hypertension        1.00      1.00      1.00         1
#                         Hyperthyroidism       1.00      1.00      1.00         1
#                            Hypoglycemia       1.00      1.00      1.00         1
#                          Hypothyroidism       1.00      1.00      1.00         1
#                                Impetigo       1.00      1.00      1.00         1
#                                Jaundice       1.00      1.00      1.00         1
#                                 Malaria       1.00      1.00      1.00         1
#                                Migraine       1.00      1.00      1.00         1
#                         Osteoarthristis       1.00      1.00      1.00         1
#            Paralysis (brain hemorrhage)       1.00      1.00      1.00         1
#                     Peptic ulcer diseae       1.00      1.00      1.00         1
#                               Pneumonia       1.00      1.00      1.00         1
#                               Psoriasis       1.00      1.00      1.00         1
#                            Tuberculosis       1.00      1.00      1.00         1
#                                 Typhoid       1.00      1.00      1.00         1
#                 Urinary tract infection       1.00      1.00      1.00         1
#                          Varicose veins       1.00      1.00      1.00         1
#                             hepatitis A       1.00      1.00      1.00         1
#
#                                accuracy                           0.98        42
#                               macro avg       0.99      0.99      0.98        42
#                            weighted avg       0.99      0.98      0.98        42
#
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7beb264923e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# FNN Test Accuracy: 0.9761904761904762
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00         1
#                                    AIDS       1.00      1.00      1.00         1
#                                    Acne       1.00      1.00      1.00         1
#                     Alcoholic hepatitis       1.00      1.00      1.00         1
#                                 Allergy       1.00      1.00      1.00         1
#                               Arthritis       1.00      1.00      1.00         1
#                        Bronchial Asthma       1.00      1.00      1.00         1
#                    Cervical spondylosis       1.00      1.00      1.00         1
#                             Chicken pox       1.00      1.00      1.00         1
#                     Chronic cholestasis       1.00      1.00      1.00         1
#                             Common Cold       1.00      1.00      1.00         1
#                                  Dengue       1.00      1.00      1.00         1
#                               Diabetes        1.00      1.00      1.00         1
#            Dimorphic hemmorhoids(piles)       1.00      1.00      1.00         1
#                           Drug Reaction       1.00      1.00      1.00         1
#                        Fungal infection       1.00      0.50      0.67         2
#                                    GERD       1.00      1.00      1.00         1
#                         Gastroenteritis       1.00      1.00      1.00         1
#                            Heart attack       1.00      1.00      1.00         1
#                             Hepatitis B       1.00      1.00      1.00         1
#                             Hepatitis C       1.00      1.00      1.00         1
#                             Hepatitis D       1.00      1.00      1.00         1
#                             Hepatitis E       1.00      1.00      1.00         1
#                           Hypertension        1.00      1.00      1.00         1
#                         Hyperthyroidism       1.00      1.00      1.00         1
#                            Hypoglycemia       1.00      1.00      1.00         1
#                          Hypothyroidism       1.00      1.00      1.00         1
#                                Impetigo       0.50      1.00      0.67         1
#                                Jaundice       1.00      1.00      1.00         1
#                                 Malaria       1.00      1.00      1.00         1
#                                Migraine       1.00      1.00      1.00         1
#                         Osteoarthristis       1.00      1.00      1.00         1
#            Paralysis (brain hemorrhage)       1.00      1.00      1.00         1
#                     Peptic ulcer diseae       1.00      1.00      1.00         1
#                               Pneumonia       1.00      1.00      1.00         1
#                               Psoriasis       1.00      1.00      1.00         1
#                            Tuberculosis       1.00      1.00      1.00         1
#                                 Typhoid       1.00      1.00      1.00         1
#                 Urinary tract infection       1.00      1.00      1.00         1
#                          Varicose veins       1.00      1.00      1.00         1
#                             hepatitis A       1.00      1.00      1.00         1
#
#                                accuracy                           0.98        42
#                               macro avg       0.99      0.99      0.98        42
#                            weighted avg       0.99      0.98      0.98        42
#
# Training Shape: (4920, 133)
# Test Shape: (42, 133)
# Nulls in Training: 0
# Unique Diseases: 41
# RF Val Accuracy: 1.0
# Epoch 1/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4357 - loss: 2.4621 - val_accuracy: 0.9980 - val_loss: 0.0605
# Epoch 2/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9861 - loss: 0.1459 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 3/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9961 - loss: 0.0437 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 4/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9970 - loss: 0.0288 - val_accuracy: 1.0000 - val_loss: 9.6631e-04
# Epoch 5/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9980 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 4.4935e-04
# Epoch 6/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9993 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 3.3375e-04
# Epoch 7/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 2.5418e-04
# Epoch 8/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 1.0514e-04
# Epoch 9/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9996 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 1.2169e-04
# Epoch 10/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 6.9095e-05
# Epoch 11/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 5.0146e-05
# Epoch 12/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9994 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 5.0006e-05
# Epoch 13/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 2.6787e-05
# Epoch 14/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 1.9289e-05
# Epoch 15/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 1.5789e-05
# Epoch 16/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 1.6869e-05
# Epoch 17/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 1.1694e-05
# Epoch 18/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9997 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 8.3105e-06
# Epoch 19/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9995 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 7.3548e-06
# Epoch 20/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 4.6005e-05
# Epoch 21/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 6.9652e-06
# Epoch 22/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.5732e-04 - val_accuracy: 1.0000 - val_loss: 3.4399e-06
# Epoch 23/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 9.1627e-04 - val_accuracy: 1.0000 - val_loss: 5.3464e-06
# Epoch 24/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9998 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 3.2849e-06
# Epoch 25/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 4.3482e-06
# Epoch 26/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 9.5166e-04 - val_accuracy: 1.0000 - val_loss: 2.7738e-06
# Epoch 27/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 2.2356e-06
# Epoch 28/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 8.0891e-06
# Epoch 29/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.5043e-04 - val_accuracy: 1.0000 - val_loss: 1.5009e-06
# Epoch 30/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.4239e-04 - val_accuracy: 1.0000 - val_loss: 2.3221e-06
# Epoch 31/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 9.5145e-07
# Epoch 32/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.8353e-04 - val_accuracy: 1.0000 - val_loss: 9.7545e-07
# Epoch 33/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 2.4538e-06
# Epoch 34/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.1576e-04 - val_accuracy: 1.0000 - val_loss: 1.6885e-06
# Epoch 35/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 1.3474e-06
# Epoch 36/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.9538e-04 - val_accuracy: 1.0000 - val_loss: 1.0429e-06
# Epoch 37/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.9372e-04 - val_accuracy: 1.0000 - val_loss: 9.1933e-07
# Epoch 38/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.9652e-04 - val_accuracy: 1.0000 - val_loss: 2.1576e-06
# Epoch 39/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9998 - loss: 7.4202e-04 - val_accuracy: 1.0000 - val_loss: 7.2727e-06
# Epoch 40/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 2.5944e-06
# Epoch 41/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.5734e-04 - val_accuracy: 1.0000 - val_loss: 6.9849e-07
# Epoch 42/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.0867e-04 - val_accuracy: 1.0000 - val_loss: 5.0431e-07
# Epoch 43/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9997 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 3.2576e-07
# Epoch 44/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 4.2128e-04 - val_accuracy: 1.0000 - val_loss: 3.2794e-07
# Epoch 45/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.4377e-04 - val_accuracy: 1.0000 - val_loss: 2.3224e-07
# Epoch 46/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.8902e-04 - val_accuracy: 1.0000 - val_loss: 1.6076e-07
# Epoch 47/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 4.2332e-04 - val_accuracy: 1.0000 - val_loss: 1.3496e-07
# Epoch 48/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 3.3763e-04 - val_accuracy: 1.0000 - val_loss: 1.2696e-07
# Epoch 49/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9998 - loss: 4.7231e-04 - val_accuracy: 1.0000 - val_loss: 1.8838e-07
# Epoch 50/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.8877e-04 - val_accuracy: 1.0000 - val_loss: 1.3290e-07
# Epoch 51/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.6552e-04 - val_accuracy: 1.0000 - val_loss: 9.2799e-08
# Epoch 52/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 3.8476e-04 - val_accuracy: 1.0000 - val_loss: 1.5446e-07
# Epoch 53/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.6721e-04 - val_accuracy: 1.0000 - val_loss: 7.4990e-08
# Epoch 54/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 4.7353e-07
# Epoch 55/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 2.2339e-07
# Epoch 56/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.1440e-04 - val_accuracy: 1.0000 - val_loss: 5.8635e-08
# Epoch 57/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.5089e-04 - val_accuracy: 1.0000 - val_loss: 1.2912e-06
# Epoch 58/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.1859e-04 - val_accuracy: 1.0000 - val_loss: 2.0195e-07
# Epoch 59/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.6291e-04 - val_accuracy: 1.0000 - val_loss: 1.1582e-07
# Epoch 60/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.1800e-04 - val_accuracy: 1.0000 - val_loss: 1.3544e-07
# Epoch 61/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.7179e-04 - val_accuracy: 1.0000 - val_loss: 7.6868e-07
# Epoch 62/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 4.5237e-04 - val_accuracy: 1.0000 - val_loss: 9.0770e-07
# Epoch 63/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0679e-04 - val_accuracy: 1.0000 - val_loss: 1.3750e-07
# Epoch 64/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4024e-04 - val_accuracy: 1.0000 - val_loss: 9.3161e-08
# Epoch 65/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9997 - loss: 4.4905e-04 - val_accuracy: 1.0000 - val_loss: 9.4857e-08
# Epoch 66/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 9.1744e-05 - val_accuracy: 1.0000 - val_loss: 6.2996e-08
# RF Test Accuracy: 0.9761904761904762
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00         1
#                                    AIDS       1.00      1.00      1.00         1
#                                    Acne       1.00      1.00      1.00         1
#                     Alcoholic hepatitis       1.00      1.00      1.00         1
#                                 Allergy       1.00      1.00      1.00         1
#                               Arthritis       1.00      1.00      1.00         1
#                        Bronchial Asthma       1.00      1.00      1.00         1
#                    Cervical spondylosis       1.00      1.00      1.00         1
#                             Chicken pox       0.50      1.00      0.67         1
#                     Chronic cholestasis       1.00      1.00      1.00         1
#                             Common Cold       1.00      1.00      1.00         1
#                                  Dengue       1.00      1.00      1.00         1
#                               Diabetes        1.00      1.00      1.00         1
#            Dimorphic hemmorhoids(piles)       1.00      1.00      1.00         1
#                           Drug Reaction       1.00      1.00      1.00         1
#                        Fungal infection       1.00      0.50      0.67         2
#                                    GERD       1.00      1.00      1.00         1
#                         Gastroenteritis       1.00      1.00      1.00         1
#                            Heart attack       1.00      1.00      1.00         1
#                             Hepatitis B       1.00      1.00      1.00         1
#                             Hepatitis C       1.00      1.00      1.00         1
#                             Hepatitis D       1.00      1.00      1.00         1
#                             Hepatitis E       1.00      1.00      1.00         1
#                           Hypertension        1.00      1.00      1.00         1
#                         Hyperthyroidism       1.00      1.00      1.00         1
#                            Hypoglycemia       1.00      1.00      1.00         1
#                          Hypothyroidism       1.00      1.00      1.00         1
#                                Impetigo       1.00      1.00      1.00         1
#                                Jaundice       1.00      1.00      1.00         1
#                                 Malaria       1.00      1.00      1.00         1
#                                Migraine       1.00      1.00      1.00         1
#                         Osteoarthristis       1.00      1.00      1.00         1
#            Paralysis (brain hemorrhage)       1.00      1.00      1.00         1
#                     Peptic ulcer diseae       1.00      1.00      1.00         1
#                               Pneumonia       1.00      1.00      1.00         1
#                               Psoriasis       1.00      1.00      1.00         1
#                            Tuberculosis       1.00      1.00      1.00         1
#                                 Typhoid       1.00      1.00      1.00         1
#                 Urinary tract infection       1.00      1.00      1.00         1
#                          Varicose veins       1.00      1.00      1.00         1
#                             hepatitis A       1.00      1.00      1.00         1
#
#                                accuracy                           0.98        42
#                               macro avg       0.99      0.99      0.98        42
#                            weighted avg       0.99      0.98      0.98        42
#
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# FNN Test Accuracy: 0.9761904761904762
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00         1
#                                    AIDS       1.00      1.00      1.00         1
#                                    Acne       1.00      1.00      1.00         1
#                     Alcoholic hepatitis       1.00      1.00      1.00         1
#                                 Allergy       1.00      1.00      1.00         1
#                               Arthritis       1.00      1.00      1.00         1
#                        Bronchial Asthma       1.00      1.00      1.00         1
#                    Cervical spondylosis       1.00      1.00      1.00         1
#                             Chicken pox       1.00      1.00      1.00         1
#                     Chronic cholestasis       1.00      1.00      1.00         1
#                             Common Cold       1.00      1.00      1.00         1
#                                  Dengue       1.00      1.00      1.00         1
#                               Diabetes        1.00      1.00      1.00         1
#            Dimorphic hemmorhoids(piles)       1.00      1.00      1.00         1
#                           Drug Reaction       1.00      1.00      1.00         1
#                        Fungal infection       1.00      0.50      0.67         2
#                                    GERD       1.00      1.00      1.00         1
#                         Gastroenteritis       1.00      1.00      1.00         1
#                            Heart attack       1.00      1.00      1.00         1
#                             Hepatitis B       1.00      1.00      1.00         1
#                             Hepatitis C       1.00      1.00      1.00         1
#                             Hepatitis D       1.00      1.00      1.00         1
#                             Hepatitis E       1.00      1.00      1.00         1
#                           Hypertension        1.00      1.00      1.00         1
#                         Hyperthyroidism       1.00      1.00      1.00         1
#                            Hypoglycemia       1.00      1.00      1.00         1
#                          Hypothyroidism       1.00      1.00      1.00         1
#                                Impetigo       0.50      1.00      0.67         1
#                                Jaundice       1.00      1.00      1.00         1
#                                 Malaria       1.00      1.00      1.00         1
#                                Migraine       1.00      1.00      1.00         1
#                         Osteoarthristis       1.00      1.00      1.00         1
#            Paralysis (brain hemorrhage)       1.00      1.00      1.00         1
#                     Peptic ulcer diseae       1.00      1.00      1.00         1
#                               Pneumonia       1.00      1.00      1.00         1
#                               Psoriasis       1.00      1.00      1.00         1
#                            Tuberculosis       1.00      1.00      1.00         1
#                                 Typhoid       1.00      1.00      1.00         1
#                 Urinary tract infection       1.00      1.00      1.00         1
#                          Varicose veins       1.00      1.00      1.00         1
#                             hepatitis A       1.00      1.00      1.00         1
#
#                                accuracy                           0.98        42
#                               macro avg       0.99      0.99      0.98        42
#                            weighted avg       0.99      0.98      0.98        42
# ['models/symptom_list.pkl']

# %%
# --- 12. LOAD DOCTOR SUGGESTION DATASET ---
doctor_df = pd.read_excel("/content/diseaseandspeci.xlsx")

# Normalize disease names for consistency
doctor_df['Disease'] = doctor_df['Disease'].str.strip().str.lower()

# --- 13. CREATE MAPPING: Disease -> Specialist ---
disease_to_doctor = {
    row['Disease']: row['Specialist']
    for _, row in doctor_df.iterrows()
}

# Save mapping
joblib.dump(disease_to_doctor, "models/disease_to_doctor_mapping.pkl")

# --- 14. DOCTOR SUGGESTION FUNCTION ---
def suggest_doctor(predicted_disease):
    """Returns doctor name and specialization for a given disease."""
    disease_key = predicted_disease.strip().lower()
    return disease_to_doctor.get(disease_key, "No doctor found for this disease")

# --- 15. SAMPLE USAGE AFTER PREDICTION ---
predicted_disease = label_encoder.inverse_transform([rf_preds_test[0]])[0]
doctor = suggest_doctor(predicted_disease)

# %% [markdown]
# # New section
